# %% [markdown]
# ## Exercise 1: Write a Pandas program to create and display a DataFrame from a specified dictionary data which has the index labels.

# %%
import pandas
import numpy as np
import pandas as pd

exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

exam_data
exam_result = pd.DataFrame(exam_data)
exam_result = pd.DataFrame(exam_data,index = ['a','b','c','d','e','f','g','h','i','j'])
exam_result
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ## Exercise 2: Write a Pandas program to select the rows where number of attempts in the examination is less than 2 and score greater than 15.
# ##### Use Data from previous problem

# %%
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
exam_result = pd.DataFrame(exam_data)

exam_result.loc[(exam_result['attempts'] < 2) & (exam_result['score'] >15)]
# Out:
#     name  score  attempts qualify
# 9  Jonas   19.0         1     yes

# %%
# Out:
# Number of attempts in the examination is less than 2 and score greater than 15 :
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %% [markdown]
# ## Exerise 3: Change the value in row 'd' to 11.5
# ##### Use Data from previous questions

# %%
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
exam_result = pd.DataFrame(exam_data)
exam_result = pd.DataFrame(exam_data,index = ['a','b','c','d','e','f','g','h','i','j'])

exam_result.at['d','score']='11.5'
exam_result
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
# Out:
# Original data frame:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
#
# Change the score in row 'd' to 11.5:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# # Exercise 4: Write a Pandas program to calculate the sum of the examination attempts by the students.
# data: d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}

# %%
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
exam_result = pd.DataFrame(exam_data)
exam_result = pd.DataFrame(exam_data,index = ['a','b','c','d','e','f','g','h','i','j'])
#df = 
exam_result['sum'] =  exam_result['attempts'].sum()
print("sum of total attempts and displayed seperately \n",exam_result)
#exam_result['sum'] =  exam_result['name'].groupby
#exam_result['name']
exam_result['groupsum']  = exam_result.groupby(['name'])['name'].sum()
print("sum of total attempts and displayed seperately \n",exam_result)
# Out:
# sum of total attempts and displayed seperately
#          name  score  attempts qualify  sum
# a  Anastasia   12.5         1     yes   19
# b       Dima    9.0         3      no   19
# c  Katherine   16.5         2     yes   19
# d      James    NaN         3      no   19
# e      Emily    9.0         2      no   19
# f    Michael   20.0         3     yes   19
# g    Matthew   14.5         1     yes   19
# h      Laura    NaN         1      no   19
# i      Kevin    8.0         2      no   19
# j      Jonas   19.0         1     yes   19
# sum of total attempts and displayed seperately
#          name  score  attempts qualify  sum groupsum
# a  Anastasia   12.5         1     yes   19      NaN
# b       Dima    9.0         3      no   19      NaN
# c  Katherine   16.5         2     yes   19      NaN
# d      James    NaN         3      no   19      NaN
# e      Emily    9.0         2      no   19      NaN
# f    Michael   20.0         3     yes   19      NaN
# g    Matthew   14.5         1     yes   19      NaN
# h      Laura    NaN         1      no   19      NaN
# i      Kevin    8.0         2      no   19      NaN
# j      Jonas   19.0         1     yes   19      NaN

# %%
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# Rows for colum1 value == 4
#    col1  col2  col3
# 1     4     5     8
# 3     4     7     0

# %% [markdown]
# ## Exercise 5: Drop a list of rows from a specified DataFrame
# ###### data:
# d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}

# %%
d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
df = pd.DataFrame(d)
#update_df = df.drop(['b', 'c'])
print("Original DataFrame \n",df)
upDf = df.drop([2,4])
print("New DataFrame after removing 2nd & 4th rows:\n",upDf)
# Out:
# Original DataFrame
#     col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# New DataFrame after removing 2nd & 4th rows:
#     col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 3     4     7     0

# %%
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# New DataFrame after removing 2nd & 4th rows:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 3     4     7     0

# %% [markdown]
# # Exercise 6:  Check whether a given column is present in a DataFrame or not
# ###### data:
# d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}

# %%
d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}
df = pd.DataFrame(d)
print(df)
A  = ['col1','col2','col3','col4']

for i in A:
        if  i in df.columns:
            print(i,'Column Available in dataframe')
        else:
            print(i,'Column not available in data frame')
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
# col1 Column Available in dataframe
# col2 Column Available in dataframe
# col3 Column Available in dataframe
# col4 Column not available in data frame

# %%
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
# Col4 is not present in DataFrame.
# Col1 is present in DataFrame.

# %% [markdown]
# ## Exercise 7: Get column index from column name of a given DataFrame
#
# ###### data:
# d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}
#
# ##### HINT: Try using a function called get_loc():
# Syntax:
# dataframe.columns.get_loc()

# %%
 d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}
df = pd.DataFrame(d)
print(df)

print('Index of col2')
df.columns.get_loc('col1')
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
# 0

# %%
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
#
# Index of 'col2'
# 1

# %% [markdown]
# ## Exercise 8: Write a Pandas program to select all columns, except one given column in a DataFrame.
# ###### Use same data as previous problem

# %%
 d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}
df = pd.DataFrame(d)
print(df)
df1 = df.loc[:, df.columns != 'col3']
print("All columns except 'col3':\n",df1)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
# All columns except 'col3':
#     col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
# 3     4     9
# 4     7     5

# %%
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12

# %%
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
#
# All columns except 'col3':
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
# 3     4     9
# 4     7     5

# %% [markdown]
# ## Exercise 9:  Write a Pandas program to remove last n rows of a given DataFrame.

# %%
 d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}
df = pd.DataFrame(d)
print(df)
print('Original DataFrame: \n',df)
#df1 = df.loc[0:2]
n = 3
#df1 = df.drop(df.tail(n).index,inplace = True)
#print('After removing last 3 rows of the said DataFrame:\n',df1)
df1 = df.drop(df.tail(n).index,inplace = True)
print('After removing last 3 rows of the said DataFrame:\n',df)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
# Original DataFrame:
#     col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
# After removing last 3 rows of the said DataFrame:
#     col1  col2  col3
# 0     1     4     7
# 1     2     5     8

# %%
# Import Required Libraries
import pandas as pd
  
# Create a dictionary for the dataframe
dict = {
  'Name': ['Sukritin', 'Sumit Tyagi', 'Akriti Goel', 
           'Sanskriti', 'Abhishek Jain'],
  'Age': [22, 20, 45, 21, 22],
   'Marks': [90, 84, -33, -87, 82]
}
  
# Converting Dictionary to 
# Pandas Dataframe
df = pd.DataFrame(dict)
  
# Number of rows to drop
n = 1
  
# Dropping last n rows using drop
df.drop(df.tail(n).index,
        inplace = True)
  
# Printing dataframe
print(df)
# Out:
#           Name  Age  Marks
# 0     Sukritin   22     90
# 1  Sumit Tyagi   20     84
# 2  Akriti Goel   45    -33
# 3    Sanskriti   21    -87

# %% [markdown]
# ## Exercise 10: Display the movies longer than 30 minutes and shorter than 360 minutes

# %%
movie_df = pd.read_csv("/Users/shkhader/DataScience/src/IMDB-Movie-Data.csv")
#movie_df.loc[movie_df['Title']
#movie_df.columns[7]  = movie_df.columns['Runtime']
df1 = movie_df.rename(columns={'Runtime (Minutes)': 'Runtime'})

df1.loc[(df1['Runtime'] > 160) & (df1['Runtime'] < 200)]
# Out:
#      Rank                                     Title                     Genre  \
# 36     37                              Interstellar    Adventure,Drama,Sci-Fi
# 55     56                                   Silence   Adventure,Drama,History
# 75     76  Pirates of the Caribbean: At World's End  Action,Adventure,Fantasy
# 82     83                   The Wolf of Wall Street    Biography,Comedy,Crime
# 87     88                                    Avatar  Action,Adventure,Fantasy
# 88     89                         The Hateful Eight       Crime,Drama,Mystery
# 117   118                                    Dangal    Action,Biography,Drama
# 124   125                     The Dark Knight Rises           Action,Thriller
# 126   127           Transformers: Age of Extinction   Action,Adventure,Sci-Fi
# 144   145                          Django Unchained             Drama,Western
# 147   148                                  Watchmen      Action,Drama,Mystery
# 225   226                            American Honey                     Drama
# 267   268                               Cloud Atlas              Drama,Sci-Fi
# 271   272         The Hobbit: An Unexpected Journey         Adventure,Fantasy
# 311   312                            La vie d'Adèle             Drama,Romance
# 425   426       The Curious Case of Benjamin Button     Drama,Fantasy,Romance
# 430   431                                  3 Idiots              Comedy,Drama
# 518   519       The Hobbit: The Desolation of Smaug         Adventure,Fantasy
# 611   612                              Toni Erdmann              Comedy,Drama
# 656   657                                   Boyhood                     Drama
# 518  Ian McKellen, Martin Freeman, Richard Armitage...  2013      161     7.9
# 611  Sandra Hüller, Peter Simonischek, Michael Witt...  2016      162     7.6
# 656  Ellar Coltrane, Patricia Arquette, Ethan Hawke...  2014      165     7.9
# 703  Nicole Kidman, Hugh Jackman, Shea Adams, Eddie...  2008      165     6.6
# 828  Kurt Russell, Rose McGowan, Danny Trejo, Zoë Bell  2007      191     7.6
# 965  Laura Dern, Jeremy Irons, Justin Theroux, Karo...  2006      180     7.0
# 991  Darsheel Safary, Aamir Khan, Tanay Chheda, Sac...  2007      165     8.5
#
#        Votes  Revenue (Millions)  Metascore
# 36   1047747              187.99       74.0
# 55     49190                7.08       79.0
# 75    498821              309.40       50.0
# 82    865134              116.87       75.0
# 87    935408              760.51       83.0
# 88    341170               54.12       68.0
# 117    48969               11.15        NaN
# 124  1222645              448.13       78.0
# 126   255483              245.43       32.0
# 144  1039115              162.80       81.0
# 147   410249              107.50       56.0
# 225    19660                0.66       79.0
# 267   298651               27.10       55.0
# 271   668651              303.00       58.0
# 311   103150                2.20       88.0
# 425   485075              127.49       70.0
# 430   238789                6.52       67.0
# 518   513744              258.36       66.0
# 611    24387                1.48       93.0
# 656   286722               25.36      100.0
# 703   106115               49.55       53.0
# 828   160350               25.03        NaN
# 965    44227                 NaN        NaN
# 991   102697                1.20       42.0

# %%
# Out:
# List of movies longer than 30 minutes and shorter than 360 minutes:
#                                        Title  Runtime (Minutes)
# 0                    Guardians of the Galaxy                121
# 1                                 Prometheus                124
# 2                                      Split                117
# 3                                       Sing                108
# 4                              Suicide Squad                123
# 5                             The Great Wall                103
# 6                                 La La Land                128
# 7                                   Mindhorn                 89
# 8                         The Lost City of Z                141
# 9                                 Passengers                116
# 10   Fantastic Beasts and Where to Find Them                133
# 11                            Hidden Figures                127
# 12                                 Rogue One                133
# 13                                     Moana                107
# 14                                  Colossal                109
# 15                   The Secret Life of Pets                 87
# 16                             Hacksaw Ridge                139
# 17                              Jason Bourne                123
# 18                                      Lion                118
# 19                                   Arrival                116
# 20                                      Gold                120
# 21                     Manchester by the Sea                137
# 22                            Hounds of Love                108
# 23                                    Trolls                 92
# 24              Independence Day: Resurgence                120
# 25                           Paris pieds nus                 83
# 26                   Bahubali: The Beginning                159
# 27                                Dead Awake                 99
# 28                                  Bad Moms                100
# 29                          Assassin's Creed                115
# ..                                       ...                ...
# 970                        Texas Chainsaw 3D                 92
# 971                                Disturbia                105
# 972                             Rock of Ages                123
# 973                                 Scream 4                111
# 974                           Queen of Katwe                124
# 975               My Big Fat Greek Wedding 2                 94
# 976                              Dark Places                113
# 977                            Amateur Night                 92
# 978           It's Only the End of the World                 97
# 979                       The Skin I Live In                120
# 980                     Miracles from Heaven                109
# 981                                    Annie                118
# 982                      Across the Universe                133
# 983                            Let's Be Cops                104
# 984                                      Max                111
# 985                            Your Highness                102
# 986                      Final Destination 5                 92
# 987                             Endless Love                104
# 988                                  Martyrs                 99
# 989                                    Selma                128
# 990           Underworld: Rise of the Lycans                 92
# 991                         Taare Zameen Par                165
# 992                     Take Me Home Tonight                 97
# 993                 Resident Evil: Afterlife                 97
# 994                                Project X                 88
# 995                     Secret in Their Eyes                111
# 996                          Hostel: Part II                 94
# 997                   Step Up 2: The Streets                 98
# 998                             Search Party                 93
# 999                               Nine Lives                 87
#
# [1000 rows x 2 columns]
